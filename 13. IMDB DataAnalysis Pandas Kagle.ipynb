# %% [markdown]
# ## Import Pandas Library

# %%
import pandas as pd

# %% [markdown]
# ## Read the datasets

# %%
movies = pd.read_csv(r'C:\Users\TANISHQ\archive\movie.csv')

# %%
ratings = pd.read_csv(r'C:\Users\TANISHQ\archive\rating.csv')

# %%
tags = pd.read_csv(r'C:\Users\TANISHQ\archive\tag.csv')

# %%
print(movies.shape)
print(ratings.shape)
print(tags.shape)
# Out:
# (27278, 3)
# (20000263, 4)
# (465564, 4)

# %%
print(movies.columns)
print(ratings.columns)
print(tags.columns)
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
tags.head()
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18

# %% [markdown]
# #### deletings columns:

# %%
del ratings['timestamp']
del tags['timestamp']

# %%
print(movies.columns)
print(ratings.columns)
print(tags.columns)
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')
# Index(['userId', 'movieId', 'rating'], dtype='object')
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %% [markdown]
# #### iloc[ ]: select and access data in DataFrames or Series using integer-based indexing
# iloc is used for purely integer-location-based indexing, meaning it selects rows based on their position in the DataFrame, not based on any label.

# %%
tags.iloc[0]  # iloc --> index location | Row indent starting from zero
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: 0, dtype: object

# %%
tags.iloc[1]
# Out:
# userId            65
# movieId          208
# tag        dark hero
# Name: 1, dtype: object

# %%
tags.iloc[2]
# Out:
# userId            65
# movieId          353
# tag        dark hero
# Name: 2, dtype: object

# %%
row_0 = tags.iloc[0]
type(row_0)
# Out:
# pandas.core.series.Series

# %%
print(row_0)
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: 0, dtype: object

# %% [markdown]
# #### .index : returns the index information of the DataFrame.

# %%
row_0.index
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
row_0['userId']
# Out:
# 18

# %%
row_0['movieId']
# Out:
# 4141

# %%
row_0['tag']
# Out:
# 'Mark Waters'

# %%
row_0.name
# Out:
# 0

# %%
row_0 = row_0.rename('firstRow') # here we named 0th row as firstRow
row_0
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: firstRow, dtype: object

# %%
tags.head(2)
# Out:
#    userId  movieId          tag
# 0      18     4141  Mark Waters
# 1      65      208    dark hero

# %%
tags.index
# Out:
# RangeIndex(start=0, stop=465564, step=1)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %% [markdown]
# #### if you want to see specific values of indexs (rows):

# %%
tags.iloc[ [0,18,500] ]
# Out:
#      userId  movieId                tag
# 0        18     4141        Mark Waters
# 18       65     3052              jesus
# 500     342    55908  entirely dialogue

# %% [markdown]
# ######

# %% [markdown]
# ## Descriptive Statistics

# %%
ratings
# Out:
#           userId  movieId  rating
# 0              1        2     3.5
# 1              1       29     3.5
# 2              1       32     3.5
# 3              1       47     3.5
# 4              1       50     3.5
# ...          ...      ...     ...
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5
#
# [20000263 rows x 3 columns]

# %%
ratings['rating'].describe()
# Out:
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
ratings.describe()
# Out:
#              userId       movieId        rating
# count  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00
# std    4.003863e+04  1.978948e+04  1.051989e+00
# min    1.000000e+00  1.000000e+00  5.000000e-01
# 25%    3.439500e+04  9.020000e+02  3.000000e+00
# 50%    6.914100e+04  2.167000e+03  3.500000e+00
# 75%    1.036370e+05  4.770000e+03  4.000000e+00
# max    1.384930e+05  1.312620e+05  5.000000e+00

# %%
ratings['rating'].mean()
# Out:
# 3.5255285642993797

# %%
ratings.mean()
# Out:
# userId     69045.872583
# movieId     9041.567330
# rating         3.525529
# dtype: float64

# %%
ratings['rating'].min()
# Out:
# 0.5

# %%
ratings['rating'].max()
# Out:
# 5.0

# %%
ratings['rating'].std()
# Out:
# 1.051988919275684

# %% [markdown]
# .mode : The mode of a set of values is the value that appears most often. It can be multiple values.
# >axis
# >
# >{0 or ‘index’, 1 or ‘columns’}, default 0
# >
# >The axis to iterate over while searching for the mode:
# >
# >0 or ‘index’ : get mode of each column
# >
# >1 or ‘columns’ : get mode of each row.

# %%
ratings['rating'].mode()  #mode: occured most times
# Out:
# 0    4.0
# Name: rating, dtype: float64

# %% [markdown]
# ######

# %% [markdown]
# ### .corr() function is used to calculate the correlation between columns in a DataFrame.
# Correlation is a measure of how closely two variables move together.
# >The correlation coefficient is a number between -1 and 1:
# >
# > 1 means a perfect positive correlation.
# >
# > -1 means a perfect negative correlation.
# >
# > 0 means no correlation.
# >
#  If you have a DataFrame with several columns of numerical data, .corr() will return a correlation matrix showing the correlation coefficients for each pair of columns.

# %%
ratings.corr()
# Out:
#            userId   movieId    rating
# userId   1.000000 -0.000850  0.001175
# movieId -0.000850  1.000000  0.002606
# rating   0.001175  0.002606  1.000000

# %% [markdown]
# ######

# %% [markdown]
# #### When you call .any() on a Series, it checks if any of the elements are True. If AT LEAST ONE ELEMENT IS TRUE, it returns True; otherwise, it returns False.

# %%
filter1 = ratings['rating'] > 10
print(filter1)
filter1.any()
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 20000258    False
# 20000259    False
# 20000260    False
# 20000261    False
# 20000262    False
# Name: rating, Length: 20000263, dtype: bool
# False

# %% [markdown]
# #### .all() function is used to check if all elements in a Series or DataFrame meet a specific condition. IF ALL ARE TRUE THEN TRUE

# %%
filter2 = ratings['rating'] >0
print(filter2)
filter2.any()
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
#             ...
# 20000258    True
# 20000259    True
# 20000260    True
# 20000261    True
# 20000262    True
# Name: rating, Length: 20000263, dtype: bool
# True

# %% [markdown]
# ## Data Cleaning: Handling Missing Data

# %%
movies.shape
# Out:
# (27278, 3)

# %%
movies.isnull().any().any() # FALSE means No NULL values
# Out:
# False

# %%
ratings.shape
# Out:
# (20000263, 3)

# %%
ratings.isnull().any().any()  #FAlSE means No NULL values !
# Out:
# False

# %%
tags.isnull().any().any()  # TRUE means have some NULL values !
# Out:
# True

# %% [markdown]
# #### to drop null values: .dropna( ) --> Remove missing values.

# %%
tags = tags.dropna()

# %%
tags.isnull().any().any()
# Out:
# False

# %%
tags.shape
# Out:
# (465548, 3)

# %% [markdown]
# ## Data Visualization

# %%
# %matplotlib inline

# %%
ratings.hist(column='rating', figsize=(10,5))
# Out:
# array([[<Axes: title={'center': 'rating'}>]], dtype=object)

# %%
ratings.boxplot(column='rating', figsize=(10,5))
# Out:
# <Axes: >

# %% [markdown]
# ## Slicing Out Columns

# %%
tags['tag'].head()
# Out:
# 0      Mark Waters
# 1        dark hero
# 2        dark hero
# 3    noir thriller
# 4        dark hero
# Name: tag, dtype: object

# %%
movies[['title','genres']].head()
# Out:
#                                 title  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings[-10:]  # last 10 indexes/rows
# Out:
#           userId  movieId  rating
# 20000253  138493    60816     4.5
# 20000254  138493    61160     4.0
# 20000255  138493    65682     4.5
# 20000256  138493    66762     4.5
# 20000257  138493    68319     4.5
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5

# %% [markdown]
# ### value_counts() function returns object containing counts of unique values.

# %%
tag_count = tags['tag'].value_counts()
tag_count
# Out:
# tag
# sci-fi                           3384
# based on a book                  3281
# atmospheric                      2917
# comedy                           2779
# action                           2657
#                                  ...
# Paul Adelstein                      1
# the wig                             1
# killer fish                         1
# genetically modified monsters       1
# topless scene                       1
# Name: count, Length: 38643, dtype: int64

# %%
tag_count[-10:]
# Out:
# tag
# missing child                    1
# Ron Moore                        1
# Citizen Kane                     1
# mullet                           1
# biker gang                       1
# Paul Adelstein                   1
# the wig                          1
# killer fish                      1
# genetically modified monsters    1
# topless scene                    1
# Name: count, dtype: int64

# %%
tag_count[:10].plot(kind='bar', figsize=(10,5)) 
#tag_count.head(10) selects the top 10 values from the tag_count series.
#plot(kind='bar') creates a bar plot.
#figsize=(10, 5) sets the size of the plot.
# Out:
# <Axes: xlabel='tag'>
